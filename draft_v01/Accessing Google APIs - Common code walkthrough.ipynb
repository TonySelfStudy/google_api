# %%
# Notes on Google API usage
# Tony Held tony.held@gmail.com
# Created 01/25/21

# Based on https://www.youtube.com/watch?v=h-gBeC9Y9cE&list=PLOU2XLYxmsILOIxBRPPhgYbuSslr50KVq&index=3

# %%
from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity I can only get last_expr_or_assign to work
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %config Completer.use_jedi = False

# %%
# API key: AIzaSyBLp6x9pNZkNOE1SW0ELHsb9cZRDyia1d8

# %% [markdown]
# ## Boilerplate for Non-Personal Data

# %%
from apiclient.discovery import build

API_KEY = "AIzaSyBLp6x9pNZkNOE1SW0ELHsb9cZRDyia1d8"
SERVICE = build(API, VERSION, developerKey=API_KEY)

# %% [markdown]
# ## Boilerplate for Personal Data

# %%
from apiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools

SCOPES = ''
CLIENT_SECRET = 'client_secret.json'

store = file.Storage('storage.json')
credz = store.get()
if not credz or credz.invalid:
    flow = client.flow_from_clientsecrets(CLIENT_SECRET)
    credz = tools.run_flow(flow, store)

SERVICE = build(API, VERSION, http=credz.authorize(Htt))

# %% [markdown]
# ## Listing files on gdrive

# %%
from apiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools

SCOPES = 'https://www.googleapis.com/auth/drive.readonly'
CLIENT_SECRET = 'client_secret.json'

store = file.Storage('storage.json')
credz = store.get()
if not credz or credz.invalid:
    flow = client.flow_from_clientsecrets(CLIENT_SECRET, SCOPES)
    credz = tools.run_flow(flow, store)

SERVICE = build('drive', 'v2', http=credz.authorize(Http()))
files = SERVICE.files().list().execute().get('items', [])

for file in files:
    print(f'{"*"*20} {file["title"]} {"*"*20}')
    for key, value in file.items():
        print(f'{key}:\t{value}')
    print()
# Out:
# ******************** workspace.xml ********************
# kind:	drive#file
# id:	1f1smt727z4qjrjoqu0n0JAshqCYSQ3-3
# etag:	"MTYxMTM3NjkzMDAwMA"
# selfLink:	https://www.googleapis.com/drive/v2/files/1f1smt727z4qjrjoqu0n0JAshqCYSQ3-3
# webContentLink:	https://drive.google.com/uc?id=1f1smt727z4qjrjoqu0n0JAshqCYSQ3-3&export=download
# alternateLink:	https://drive.google.com/file/d/1f1smt727z4qjrjoqu0n0JAshqCYSQ3-3/view?usp=drivesdk
# embedLink:	https://drive.google.com/file/d/1f1smt727z4qjrjoqu0n0JAshqCYSQ3-3/preview?usp=drivesdk
# iconLink:	https://drive-thirdparty.googleusercontent.com/16/type/application/xml
# title:	workspace.xml
# mimeType:	application/xml
# labels:	{'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'viewed': False}
# copyRequiresWriterPermission:	False
# createdDate:	2020-10-02T19:56:14.186Z
# modifiedDate:	2021-01-23T04:42:10.000Z
# modifiedByMeDate:	2021-01-23T04:42:10.000Z
# markedViewedByMeDate:	1970-01-01T00:00:00.000Z
# version:	3506
# ...

# %%
pwd
# Out:
# 'D:\\Google Drive\\My Documents\\code\\python\\Pycharm Projects\\Self Study\\GoogleCalendar'
